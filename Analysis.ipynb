# %%
import pandas as pd
import numpy as np

# %%
tobacco_use_us = pd.read_csv("tobacco_use_us.csv")
tobacco_use_ww = pd.read_csv("tobacco_use_ww.csv")
us_chronic_resp_disease = pd.read_csv("us_chronic_resp_disease.csv")
death_rates_smoking_age = pd.read_csv("death_rates_smoking_age.csv")
sales_per_day = pd.read_csv("sales_per_day.csv")
stop_smoking = pd.read_csv("stop_smoking.csv")
tobacco_production = pd.read_csv("tobacco_production.csv")

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

tobacco_production.head(10)
# Out:
#   Country or Area  Year         Unit        Value Value Footnotes
# 0         Albania  2006  Metric tons   546.600000             NaN
# 1         Albania  2006     Mil. USD     1.324113             NaN
# 2         Albania  2005  Metric tons  1878.500000             NaN
# 3         Albania  2005     Mil. USD     4.844285             NaN
# 4         Albania  2004  Metric tons   751.900000             NaN
# 5         Albania  2004     Mil. USD     2.517025             NaN
# 6         Algeria  2015  Metric tons  7483.000000             NaN
# 7         Algeria  2014  Metric tons  7648.000000             NaN
# 8         Algeria  2013  Metric tons  8241.000000             NaN
# 9         Algeria  2012  Metric tons  8130.000000             NaN

# %%
Brazil_production = tobacco_production[tobacco_production['Country or Area'] == 'Brazil']
Turkey_production = tobacco_production[tobacco_production['Country or Area'] == 'Turkey']

# %%
Brazil_tobacco_use = tobacco_use_ww[tobacco_use_ww['Location'] == 'Brazil']
Turkey_tobacco_use = tobacco_use_ww[tobacco_use_ww['Location'] == 'Turkey']

# %%
Brazil_tobacco_use
# Out:
#      ParentLocationCode ParentLocation SpatialDimValueCode Location  Year  \
# 39                  AMR       Americas                 BRA   Brazil  2018
# 93                  AMR       Americas                 BRA   Brazil  2018
# 159                 AMR       Americas                 BRA   Brazil  2018
# 490                 AMR       Americas                 BRA   Brazil  2017
# 546                 AMR       Americas                 BRA   Brazil  2017
# 614                 AMR       Americas                 BRA   Brazil  2017
# 941                 AMR       Americas                 BRA   Brazil  2016
# 994                 AMR       Americas                 BRA   Brazil  2016
# 1068                AMR       Americas                 BRA   Brazil  2016
# 1387                AMR       Americas                 BRA   Brazil  2015
# 1442                AMR       Americas                 BRA   Brazil  2015
# 1521                AMR       Americas                 BRA   Brazil  2015
# ...

# %%
stop_smoking
# Out:
#                                Entity Code  Year  AvgCigarettePriceDollars  \
# 0                             Algeria  DZA  2012                      1.84
# 1                             Algeria  DZA  2014                      2.09
# 2                           Argentina  ARG  2012                      2.79
# 3                           Argentina  ARG  2014                      3.47
# 4                             Armenia  ARM  2012                      1.69
# 5                             Armenia  ARM  2014                      1.74
# 6                           Australia  AUS  2012                      8.24
# 7                           Australia  AUS  2014                     10.64
# 8                             Austria  AUT  2012                      4.97
# 9                             Austria  AUT  2014                      5.34
# 10                         Azerbaijan  AZE  2012                      1.75
# ...
